# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import gensim.downloader as api
import re

# Read the CSV file
data = pd.read_csv('Day_3.csv')

# Extract the text and label columns
texts = data['Message'].tolist()
labels = [f"source={source} destination={destination}" for source, destination in zip(data['Source'], data['Destination'])]

# Convert texts and labels to lowercase
texts = [text.lower().strip() for text in texts]

labels = [label.lower().strip() for label in labels]

# Encode labels
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)

# Tokenize and pad sequences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
max_sequence_length = max(len(sequence) for sequence in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length)

# Load GloVe word embeddings
word_embeddings = api.load("glove-wiki-gigaword-300")  # Load GloVe embeddings

# Create an embedding matrix
embedding_dimension = word_embeddings.vector_size
word_index = tokenizer.word_index
embedding_matrix = np.zeros((len(word_index) + 1, embedding_dimension))

for word, index in word_index.items():
    if word in word_embeddings:
        embedding_matrix[index] = word_embeddings[word]

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, encoded_labels, test_size=0.2, random_state=42)

# Build LSTM model with its own embedding layer
model = Sequential()
model.add(Embedding(len(word_index) + 1, embedding_dimension, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False))
model.add(Bidirectional(LSTM(128, return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, return_sequences=True)))
model.add(Bidirectional(LSTM(64)))
model.add(Dense(32, activation='relu'))
model.add(Dense(len(label_encoder.classes_), activation='softmax'))

# Compile and train the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=70, batch_size=256, validation_data=(X_test, y_test))
# Out:
# <ipython-input-1-d086535f5ce9>:13: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Day_3.csv')
# [==================================================] 100.0% 376.1/376.1MB downloaded
# Epoch 1/70
# 231/231 [==============================] - 39s 101ms/step - loss: 7.9495 - accuracy: 0.0249 - val_loss: 7.7901 - val_accuracy: 0.0271
# Epoch 2/70
# 231/231 [==============================] - 21s 91ms/step - loss: 7.5857 - accuracy: 0.0264 - val_loss: 7.7899 - val_accuracy: 0.0271
# Epoch 3/70
# 231/231 [==============================] - 22s 97ms/step - loss: 7.1855 - accuracy: 0.0302 - val_loss: 6.9573 - val_accuracy: 0.0431
# Epoch 4/70
# 231/231 [==============================] - 22s 96ms/step - loss: 6.4568 - accuracy: 0.0554 - val_loss: 6.3192 - val_accuracy: 0.0762
# Epoch 5/70
# 231/231 [==============================] - 23s 101ms/step - loss: 5.7105 - accuracy: 0.1185 - val_loss: 5.7516 - val_accuracy: 0.1838
# Epoch 6/70
# 231/231 [==============================] - 23s 100ms/step - loss: 5.0561 - accuracy: 0.2016 - val_loss: 5.3012 - val_accuracy: 0.2556
# Epoch 7/70
# 231/231 [==============================] - 23s 99ms/step - loss: 4.5518 - accuracy: 0.2823 - val_loss: 4.9836 - val_accuracy: 0.3107
# Epoch 8/70
# 231/231 [==============================] - 23s 98ms/step - loss: 4.1688 - accuracy: 0.3312 - val_loss: 4.7728 - val_accuracy: 0.3555
# Epoch 9/70
# 231/231 [==============================] - 23s 101ms/step - loss: 3.7683 - accuracy: 0.3743 - val_loss: 4.5560 - val_accuracy: 0.3976
# Epoch 10/70
# 231/231 [==============================] - 23s 99ms/step - loss: 3.4064 - accuracy: 0.4071 - val_loss: 4.4305 - val_accuracy: 0.4261
# Epoch 11/70
# 231/231 [==============================] - 23s 99ms/step - loss: 3.0815 - accuracy: 0.4391 - val_loss: 4.2944 - val_accuracy: 0.4567
# Epoch 12/70
# 231/231 [==============================] - 23s 99ms/step - loss: 2.8009 - accuracy: 0.4672 - val_loss: 4.2428 - val_accuracy: 0.4778
# Epoch 13/70
# 231/231 [==============================] - 23s 101ms/step - loss: 2.5528 - accuracy: 0.4891 - val_loss: 4.1446 - val_accuracy: 0.5042
# Epoch 14/70
# 231/231 [==============================] - 23s 101ms/step - loss: 2.3826 - accuracy: 0.5062 - val_loss: 4.1124 - val_accuracy: 0.5096
# Epoch 15/70
# 231/231 [==============================] - 23s 99ms/step - loss: 2.1616 - accuracy: 0.5301 - val_loss: 4.0694 - val_accuracy: 0.5264
# Epoch 16/70
# 231/231 [==============================] - 23s 99ms/step - loss: 1.9682 - accuracy: 0.5503 - val_loss: 4.0153 - val_accuracy: 0.5473
# Epoch 17/70
# 231/231 [==============================] - 23s 101ms/step - loss: 1.8073 - accuracy: 0.5685 - val_loss: 4.0000 - val_accuracy: 0.5591
# Epoch 18/70
# 231/231 [==============================] - 23s 102ms/step - loss: 1.6641 - accuracy: 0.5863 - val_loss: 3.9863 - val_accuracy: 0.5723
# Epoch 19/70
# 231/231 [==============================] - 24s 102ms/step - loss: 1.5308 - accuracy: 0.6040 - val_loss: 3.9642 - val_accuracy: 0.5900
# Epoch 20/70
# 231/231 [==============================] - 24s 102ms/step - loss: 1.4173 - accuracy: 0.6186 - val_loss: 3.9425 - val_accuracy: 0.5965
# Epoch 21/70
# 231/231 [==============================] - 23s 102ms/step - loss: 1.3239 - accuracy: 0.6314 - val_loss: 3.9194 - val_accuracy: 0.6041
# Epoch 22/70
# 231/231 [==============================] - 23s 102ms/step - loss: 1.2448 - accuracy: 0.6429 - val_loss: 3.9319 - val_accuracy: 0.6106
# Epoch 23/70
# 231/231 [==============================] - 23s 101ms/step - loss: 1.1725 - accuracy: 0.6546 - val_loss: 3.8602 - val_accuracy: 0.6168
# Epoch 24/70
# 231/231 [==============================] - 23s 101ms/step - loss: 1.1156 - accuracy: 0.6614 - val_loss: 3.8981 - val_accuracy: 0.6229
# Epoch 25/70
# 231/231 [==============================] - 23s 99ms/step - loss: 1.0675 - accuracy: 0.6695 - val_loss: 3.8294 - val_accuracy: 0.6355
# Epoch 26/70
# 231/231 [==============================] - 23s 102ms/step - loss: 1.0232 - accuracy: 0.6770 - val_loss: 3.8456 - val_accuracy: 0.6371
# Epoch 27/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.9812 - accuracy: 0.6860 - val_loss: 3.8197 - val_accuracy: 0.6337
# Epoch 28/70
# 231/231 [==============================] - 23s 102ms/step - loss: 0.9508 - accuracy: 0.6885 - val_loss: 3.8112 - val_accuracy: 0.6483
# Epoch 29/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.9126 - accuracy: 0.6958 - val_loss: 3.7793 - val_accuracy: 0.6504
# Epoch 30/70
# 231/231 [==============================] - 24s 102ms/step - loss: 0.8966 - accuracy: 0.6997 - val_loss: 3.7391 - val_accuracy: 0.6592
# Epoch 31/70
# 231/231 [==============================] - 23s 100ms/step - loss: 0.8658 - accuracy: 0.7063 - val_loss: 3.7269 - val_accuracy: 0.6585
# Epoch 32/70
# 231/231 [==============================] - 23s 100ms/step - loss: 0.8364 - accuracy: 0.7093 - val_loss: 3.7238 - val_accuracy: 0.6676
# Epoch 33/70
# 231/231 [==============================] - 24s 102ms/step - loss: 0.8220 - accuracy: 0.7115 - val_loss: 3.7435 - val_accuracy: 0.6555
# Epoch 34/70
# 231/231 [==============================] - 24s 102ms/step - loss: 0.8068 - accuracy: 0.7159 - val_loss: 3.6860 - val_accuracy: 0.6640
# Epoch 35/70
# 231/231 [==============================] - 24s 102ms/step - loss: 0.7923 - accuracy: 0.7160 - val_loss: 3.6528 - val_accuracy: 0.6751
# Epoch 36/70
# 231/231 [==============================] - 24s 102ms/step - loss: 0.7741 - accuracy: 0.7190 - val_loss: 3.6372 - val_accuracy: 0.6745
# Epoch 37/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.7619 - accuracy: 0.7214 - val_loss: 3.5904 - val_accuracy: 0.6711
# Epoch 38/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.7465 - accuracy: 0.7233 - val_loss: 3.5793 - val_accuracy: 0.6723
# Epoch 39/70
# 231/231 [==============================] - 24s 102ms/step - loss: 0.7386 - accuracy: 0.7244 - val_loss: 3.5570 - val_accuracy: 0.6755
# Epoch 40/70
# 231/231 [==============================] - 23s 101ms/step - loss: 0.7223 - accuracy: 0.7306 - val_loss: 3.5083 - val_accuracy: 0.6702
# Epoch 41/70
# 231/231 [==============================] - 23s 101ms/step - loss: 0.7176 - accuracy: 0.7291 - val_loss: 3.5186 - val_accuracy: 0.6736
# Epoch 42/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.7036 - accuracy: 0.7298 - val_loss: 3.4584 - val_accuracy: 0.6742
# Epoch 43/70
# 231/231 [==============================] - 23s 101ms/step - loss: 0.6945 - accuracy: 0.7323 - val_loss: 3.4528 - val_accuracy: 0.6752
# Epoch 44/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.6838 - accuracy: 0.7343 - val_loss: 3.4505 - val_accuracy: 0.6738
# Epoch 45/70
# 231/231 [==============================] - 24s 102ms/step - loss: 0.6787 - accuracy: 0.7338 - val_loss: 3.3891 - val_accuracy: 0.6826
# Epoch 46/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.6732 - accuracy: 0.7350 - val_loss: 3.3910 - val_accuracy: 0.6736
# Epoch 47/70
# 231/231 [==============================] - 23s 98ms/step - loss: 0.6581 - accuracy: 0.7365 - val_loss: 3.3039 - val_accuracy: 0.6805
# Epoch 48/70
# 231/231 [==============================] - 23s 98ms/step - loss: 0.6560 - accuracy: 0.7374 - val_loss: 3.3237 - val_accuracy: 0.6791
# Epoch 49/70
# 231/231 [==============================] - 23s 98ms/step - loss: 0.6508 - accuracy: 0.7372 - val_loss: 3.3212 - val_accuracy: 0.6771
# Epoch 50/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.6395 - accuracy: 0.7388 - val_loss: 3.2406 - val_accuracy: 0.6816
# Epoch 51/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.6358 - accuracy: 0.7383 - val_loss: 3.2540 - val_accuracy: 0.6703
# Epoch 52/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.6283 - accuracy: 0.7408 - val_loss: 3.2171 - val_accuracy: 0.6811
# Epoch 53/70
# 231/231 [==============================] - 23s 101ms/step - loss: 0.6251 - accuracy: 0.7408 - val_loss: 3.2183 - val_accuracy: 0.6844
# Epoch 54/70
# 231/231 [==============================] - 23s 101ms/step - loss: 0.6206 - accuracy: 0.7421 - val_loss: 3.1711 - val_accuracy: 0.6782
# Epoch 55/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.6156 - accuracy: 0.7407 - val_loss: 3.2160 - val_accuracy: 0.6784
# Epoch 56/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.6136 - accuracy: 0.7415 - val_loss: 3.1434 - val_accuracy: 0.6804
# Epoch 57/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.6060 - accuracy: 0.7440 - val_loss: 3.1176 - val_accuracy: 0.6740
# Epoch 58/70
# 231/231 [==============================] - 23s 102ms/step - loss: 0.6028 - accuracy: 0.7427 - val_loss: 3.0935 - val_accuracy: 0.6743
# Epoch 59/70
# 231/231 [==============================] - 23s 102ms/step - loss: 0.5947 - accuracy: 0.7435 - val_loss: 3.0808 - val_accuracy: 0.6786
# Epoch 60/70
# 231/231 [==============================] - 23s 98ms/step - loss: 0.5956 - accuracy: 0.7415 - val_loss: 3.1042 - val_accuracy: 0.6734
# Epoch 61/70
# 231/231 [==============================] - 23s 101ms/step - loss: 0.5932 - accuracy: 0.7433 - val_loss: 3.0441 - val_accuracy: 0.6734
# Epoch 62/70
# 231/231 [==============================] - 23s 101ms/step - loss: 0.5879 - accuracy: 0.7439 - val_loss: 3.0152 - val_accuracy: 0.6718
# Epoch 63/70
# 231/231 [==============================] - 23s 101ms/step - loss: 0.5788 - accuracy: 0.7448 - val_loss: 3.0157 - val_accuracy: 0.6775
# Epoch 64/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.5741 - accuracy: 0.7443 - val_loss: 3.0113 - val_accuracy: 0.6824
# Epoch 65/70
# 231/231 [==============================] - 23s 101ms/step - loss: 0.5724 - accuracy: 0.7472 - val_loss: 3.0172 - val_accuracy: 0.6802
# Epoch 66/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.5696 - accuracy: 0.7446 - val_loss: 2.9569 - val_accuracy: 0.6861
# Epoch 67/70
# 231/231 [==============================] - 23s 101ms/step - loss: 0.5660 - accuracy: 0.7478 - val_loss: 2.9795 - val_accuracy: 0.6799
# Epoch 68/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.5682 - accuracy: 0.7440 - val_loss: 2.9587 - val_accuracy: 0.6785
# Epoch 69/70
# 231/231 [==============================] - 23s 101ms/step - loss: 0.5670 - accuracy: 0.7449 - val_loss: 2.9801 - val_accuracy: 0.6791
# Epoch 70/70
# 231/231 [==============================] - 23s 99ms/step - loss: 0.5599 - accuracy: 0.7465 - val_loss: 2.9488 - val_accuracy: 0.6807

# %%
#model.save_weights('SD70ep.h5')

# %%
for i in range(200):
    m = df.iloc[i, 1]
    predefined_string = str(m)

    user_sequence = tokenizer.texts_to_sequences([predefined_string])
    user_padded_sequence = pad_sequences(user_sequence, maxlen=max_sequence_length)

    # Predict features of predefined string
    predicted_label = model.predict(user_padded_sequence)  # Perform the prediction

    predicted_label_index = np.argmax(predicted_label)
    decoded_label = label_encoder.inverse_transform([predicted_label_index])[0]

    # Print the predicted label
    print("Predicted label:", decoded_label.title())
    print(df.lloc[i,'Message'])
    print()
# Out:
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source= Shirdi Destination=Nashik Station
# Sedan Car Shirdi To Kurla Station Drop 1 Pm 8856000999
#
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source=Mumbai Thane Destination=Khed Dapoli
# Available Mumbai Thane To Khed Dapoli Drop Tomorrow 5:00 A.M. Sedan Car Me 9029650197
#
# 1/1 [==============================] - 0s 34ms/step
# Predicted label: Source= Pune Destination=Ratnagiri
# 2 Days Round Trip Pune To Ratnagiri Car Type :- Ertiga Disel New Time :- Tomorrow 6 Am Me :- 9768868301
#
# 1/1 [==============================] - 0s 37ms/step
# Predicted label: Source=Panchgani Destination=Pune
# Panchgani To Pune Drop Innova & Eritka 7Seat Urgent Me 72197 67606
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source= Kolhapur Destination=Mumbai
# Advance Innova With Carrie 12/04/23 6:30 Kolhapur To Mumbai ( ) Drop . All Including 7500 Rohit 9922647446 Gp Advance Campalsri No Ertiga Only Innova
#
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source=Shirdi Destination=Mumbai
# Shirdi To Mumbai Kulaba Drop Swift Dizer Arjent Any Interest Mi 9860331325
#
# 1/1 [==============================] - 0s 35ms/step
# Predicted label: Source= Ahmednagar Destination=Mumbai Airport
# Sedan Car Pm Ahmednagar To Mumbai Airport Drop 9767969076
#
# 1/1 [==============================] - 0s 37ms/step
# Predicted label: Source=Ahmednagar Destination=Pune
# Ahmednagar To Pune Drop Today 8Am Any Hatchback Or Sedan Rs 1800 All Including 9370488503
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source=Rajkot  Destination=Pune
# Ertiga Cab Rajkot City To Pune City Tomorrow Morning- 05.30 Am Date - 07 April 2023 10 000 Rs All Included. Rajesh- India Tourism. 9820020313 Note- . Note- This Is Private Booking. Note- Neat And Clean Only.
#
# 1/1 [==============================] - 0s 49ms/step
# Predicted label: Source=Latur Destination=Pune
# Latur To Pune Ky Asla Tar Sang Sedan Mt Yeta Ahe Aaja 9307736020
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source=Pune Airport Destination=Shirdi
# Arjunt Sedan Pune Airport To Shirdi Drop Me 9860467173
#
# 1/1 [==============================] - 0s 37ms/step
# Predicted label: Source= Panchgani Destination=Pune
# Date 06/04/23 Pickup :10:00Am Panchgani To Pune Drop Ertiga Contact Number 8888656706 Only Nearby Thanks
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source=Mumbai  Destination=Pune
# Only Near By Hatchback One Way Drop Mumbai Cst To Pune Drop Urgent 9975497474
#
# 1/1 [==============================] - 0s 37ms/step
# Predicted label: Source= Bhandup Destination=Satara Sangli
# Mumbai Cab'S Tata Winger Or Cruiser A/C ( ) - Bhandup Mumbai - Satara Sangli Returned Bhandup Date:- 07/04/2023 To 10 /04/2023 Time:- 05:00 Am :- Bhandup To Satara Sangli Return Type:- 4 Day Round Trip Rate:- 300Km Avarage Toll Parking Driver Food Extra Near By Mumbai Cab'S +91 9967483858 / 9819758508
#
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source=Shirdi Destination=Mahabaleshwar
# Shirdi To Nashik Trambkeswar Drop Swift Dizer One Way Any Interest Mi .9860331325
#
# 1/1 [==============================] - 0s 49ms/step
# Predicted label: Source=Mumbai Mahape Destination=Nashik
# Mahabaleshwar To Nashik Drop Only Eitos 6-4-23 Morning 10Am Contact -9970304228
#
# 1/1 [==============================] - 0s 45ms/step
# Predicted label: Source=Mumbai Destination=Nashik
# Mumbai To Nashik Drop Time. Urjant Sedan Car Manoj 9892355559
#
# 1/1 [==============================] - 0s 44ms/step
# Predicted label: Source=Pune Destination=Mumbai
# Pune To Mumbai Return Only Eitos 6-4-23 Contact -9730792192
#
# 1/1 [==============================] - 0s 67ms/step
# Predicted label: Source= Mumbai Destination=Pune
# Urjent Only Neyer By T 2 Mumbai To Pune Dhayari Sedan Mo 9373110361/8691930432 Rs 2200
#
# 1/1 [==============================] - 0s 50ms/step
# Predicted label: Source=Vapi Destination=Nashik
# _My Car Hyundai Xcent (4+1)_ _Going To Gujarat ( )Drop _ _Free Time 7.00 Pm _Any Booking_ Surat Vapi To Nashik Drop_ _Please Me_ _Chetan Kulthe _8055352069_
#
# 1/1 [==============================] - 0s 69ms/step
# Predicted label: Source=Pune  Destination=Mumbai
# New Model Swift Dizair Going For Mahableshor Drop Free Free Free Any Mahableshor To Nashik Mahableshor To Pune Mahableshor To Mumbai Plzz Call 9503622786 7373738997
#
# 1/1 [==============================] - 0s 44ms/step
# Predicted label: Source=Nashik Destination=Ahmedabad
# Nashik To Ahmedabad Drap Only Swift Dzire Time Argent Please Me Suresh Mama 9172264562
#
# 1/1 [==============================] - 0s 48ms/step
# Predicted label: Source= Mumbai Destination=Shirdi
# Advance Innova One Day Round Trip Mumbai To Shirdi Date 7 Time 4 Am 9975497474
#
# 1/1 [==============================] - 0s 48ms/step
# Predicted label: Source=Mumbai Airport Destination=Pune
# Only Exchange - Mumbai Airpot To Pune Drop 6 Pm Innova Crysta & - Excnt Diesel Sedan Mumbai Airport To Pune Day Exchange Sagar= 7397820427 9022486201
#
# 1/1 [==============================] - 0s 53ms/step
# Predicted label: Source= Pune Destination=Nagpur
# !! Booking!!!!!! Need Sedan Pune To Nagpur Time : 9 Pm Rate : ? Call Me For Fast 7887729582
#
# 1/1 [==============================] - 0s 41ms/step
# Predicted label: Source=Kopargaon Destination=Nagar
# Nagpur To Amravati Drop Time Urgentonly Swift Dzire Me Suresh Mama 9860423919
#
# 1/1 [==============================] - 0s 52ms/step
# Predicted label: Source=Pune Destination=Amravati
# Pune To Amravati Drop Time Urgentonly Swift Dzire Me Suresh Mama 9860423919
#
# 1/1 [==============================] - 0s 51ms/step
# Predicted label: Source= Mumbai Destination=Nashik
# !!! ..Prajwal Tourism ..!!! Exchange Only Car. Sedan Collection. 2500 Date. 6 April 2023 Time. 6:30 Mumbai To Nashik Drop - Car. Verna Sedan Date. 5 April 23 Time. Free Mumbai To Nashik Drop Call. 7776856987 / 8668437192 !!! Thank You ..!!!
#
# 1/1 [==============================] - 0s 53ms/step
# Predicted label: Source=Shirdi Destination=Nashik
# Shirdi To Nashik Drop Swift Dizire 12.30Pm 9511750005 9637011073
#
# 1/1 [==============================] - 0s 51ms/step
# Predicted label: Source=Pune Destination=Mumbai
# Pune To Mumbai Drop Today 12:30 Pm Any Sedan Car Rs 2200 All Including 9970260783
#
# 1/1 [==============================] - 0s 50ms/step
# Predicted label: Source=Mumbai Airport Destination= Road
# Transfer Innova Crysta Time - 12 Pm Mumbai Airport To Mira Road Drop 7774985111
#
# 1/1 [==============================] - 0s 53ms/step
# Predicted label: Source=Pune Destination=Nashik
# Pune To Nashik Drop 12:30 Pm Today Only Innova Car Please Me No Tempass New Sonu Trvalas 8208660941 7746024530
#
# 1/1 [==============================] - 0s 51ms/step
# Predicted label: Source=Nashik  Destination=Mulund
# Nashik Trambakeshwar To Mulund Drop Only Swift Dzire Diesel Time 10:30 A.M. Me Suresh Mama 9860423919
#
# 1/1 [==============================] - 0s 46ms/step
# Predicted label: Source= Baramati Destination=Mumbai
# Time 10.00 Am Any Sedan Cab Only Drop Baramati To Mumbai Drop Cash 4000/- Including Me 8999240812
#
# 1/1 [==============================] - 0s 44ms/step
# Predicted label: Source=Bandra Mumbai Destination=Pune
# For Ertiga Parcel Dog 3000 Bandra Mumbai To Pune Warje 8308287877
#
# 1/1 [==============================] - 0s 60ms/step
# Predicted label: Source= Igatpuri Destination=Mumbai Airport
# Sedan Car Igatpuri To Mumbai Airport 7021320869
#
# 1/1 [==============================] - 0s 53ms/step
# Predicted label: Source=Aurangabad  Destination=Ahmednagar
# Aurangabad Midc To Ahmednagar Drop Time. Urgent Car Sedan Parcel Hai Basket 3 Dicky Wala Gadi Mein Baith Jata Hai Mm 9922786318
#
# 1/1 [==============================] - 0s 43ms/step
# Predicted label: Source= Ratnagiri Destination=Mahad
# Tomorrow Morning 7 Am Sedan Car Req Ratnagiri To Mahad 2 Hours Halt Than Thane Mumbai Drop 4500 All Include Interested 8421999311
#
# 1/1 [==============================] - 0s 50ms/step
# Predicted label: Source= Kolhapur Destination=Borivali
# Sedan Time Urgent 7 O Clock Kolhapur To Borivali 9326473180
#
# 1/1 [==============================] - 0s 58ms/step
# Predicted label: Source= Pune Destination=Karmala
# Bookin Time Urgent Pune To Karmala Drop Ertiga Cab 3300 All Includin 8668439610
#
# 1/1 [==============================] - 0s 56ms/step
# Predicted label: Source=Ahmednagar Destination=Mumbai
# Ahmednagar To Mumbai Bahendra Drop Time. Urgent Car Sedan Mm 9922786318
#
# 1/1 [==============================] - 0s 48ms/step
# Predicted label: Source= Shirdi Destination=Pune
# Only Eartiga Shirdi To Pune Urgent 9518708741
#
# 1/1 [==============================] - 0s 47ms/step
# Predicted label: Source= Shirdi Destination=Pune
# Only Eartiga Shirdi To Pune Urgent 9518708741
#
# 1/1 [==============================] - 0s 44ms/step
# Predicted label: Source=Ahmednagar Destination=Pune
# Ahmednagar To Pune Yevlewadi Drop Today 3Pm Any Hatchback Or Sedan Rs 1800 All Including 9370488503
#
# 1/1 [==============================] - 0s 54ms/step
# Predicted label: Source= Nagar Destination=Nashik
# Need = Sedan Viman Nagar To Nashik Drop Time = Urjent Only Viman Nagar Vehicle =9834436627
#
# 1/1 [==============================] - 0s 50ms/step
# Predicted label: Source=Shirdi Destination=Pune
# Shirdi To Pune Drop Swift Dizire 1Pm 9511750005 9637011073
#
# 1/1 [==============================] - 0s 43ms/step
# Predicted label: Source= Shirdi Destination=Mumbai
# Time Arjant Shirdi To Mumbai Drop Required Suv Ertiga Innova Please 8668515898
#
# 1/1 [==============================] - 0s 44ms/step
# Predicted label: Source= Mahabaleshwar Destination=Pune Airport
# Advance Date 05/04/23 Pickup :08:00Pm Solapur To Pune Airport Dezire Xcent Contact Number 7058376670 Only Nearby Thanks
#
# 1/1 [==============================] - 0s 34ms/step
# Predicted label: Source=Shirdi Destination=Mumbai
# Shirdi To Mumbai Drop Ertika 12Pm 9511750005 9637011073
#
# 1/1 [==============================] - 0s 34ms/step
# Predicted label: Source=Mumbai Destination=Nashik
# Mumbai To Nashik Need : Sedan Time : 10.30Am Any One Intrested Me Kalpesh 8888465888
#
# 1/1 [==============================] - 0s 35ms/step
# Predicted label: Source= Karad Destination=Pune
# Sedan Igatpuri To Pune Drop Time 10:00Am 9588463277 Only Advance Payment
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source=Panchgani Destination=Pune
# Panchgani To Pune Drop Today 10:30Am Only Ertica Rs.. 9370488503
#
# 1/1 [==============================] - 0s 37ms/step
# Predicted label: Source=Pune  Destination=Matheran
# Arjent Only Innova Pune Handewadi To Matheran Drop 9768711919
#
# 1/1 [==============================] - 0s 38ms/step
# Predicted label: Source=Mumbai Airport Destination=Pune
# Innova Crysta Only Mumbai Airport To Pune Drop Morning 9 Am 9552737170
#
# 1/1 [==============================] - 0s 38ms/step
# Predicted label: Source= Ratnagiri Destination=Mahad
# Advance 5/4/2023 Need Sedan Neat And Clean Ratnagiri To Mahad Drop 2800 All Include Interested 8421999311
#
# 1/1 [==============================] - 0s 39ms/step
# Predicted label: Source=Mumbai Airport Destination=Pune
# Mumbai Airport To Pune Drop Sedan Car Requirement Pick-Up Time Urgent Cash . 2500 All Including Advance Google Pay Phone Pay Mob.+919730073828
#
# 1/1 [==============================] - 0s 35ms/step
# Predicted label: Source=Pune  Destination=Mumbai
# Pune Kondva To Mumbai Goreghav Drop Cab Sedan Pickup 11.00Pm Interested Me 9146311536
#
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source= Pune Destination=Nashik
# Only Innova Crysta Pune To Nashik Trambakeshwar Return Me Urgently 7507076003
#
# 1/1 [==============================] - 0s 31ms/step
# Predicted label: Source=Nashik Destination=Aurangabad
# Nashik To Aurangabad Drop Round Trip Sedan 04/04/23 & 05/04/23 7974756994 Advance Phone Pay
#
# 1/1 [==============================] - 0s 31ms/step
# Predicted label: Source= Pune Destination=Mumbai
# Innova Cryata With Carrier Pune To Mumbai 10 9518708741
#
# 1/1 [==============================] - 0s 38ms/step
# Predicted label: Source=Virar Destination=Koregaon
# Virar To Koregaon Park Pune Drop Today 8:30Pm Sedan Rs : 2700+ Toll 8830042078
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source= Ratnagiri Destination=Mahad
# Advance 5/04/2023 Required 2 Sedan Neat And Clean 1.Ratnagiri To Mahad Drop. Rate - 2800 2. Ratnagiri To Mahad 2 Hours Halt Than Thane Mumbai Drop. Rate - 4500 All Included Interested Plz Call Me 8421999311
#
# 1/1 [==============================] - 0s 38ms/step
# Predicted label: Source=Mahabaleshwar Destination=Pune
# Mahabaleshwar To Pune Hadapsar Stn Drop Tomorrow 10Am Morning Sedan Car With Carrier Amt- 0000 Mo No. 8055788612
#
# 1/1 [==============================] - 0s 34ms/step
# Predicted label: Source=Nashik Destination=Thane
# Nashik To Thane Any Hatchback 5 Pm Mb:9518765505
#
# 1/1 [==============================] - 0s 40ms/step
# Predicted label: Source=Pune  Destination=Miraj
# Required Sedan Cab Pune Swargate To Miraj Drop Rs2800 All Including Interested Me 9527379527 Rajveer Tours And Travels
#
# 1/1 [==============================] - 0s 35ms/step
# Predicted label: Source=Nashik Destination=Dhule
# Nashik To Dhule Drop Today 3Pm Only Sedan Rs 2500 All Including 9370488503
#
# 1/1 [==============================] - 0s 34ms/step
# Predicted label: Source= Kolhapur Destination=Pune
# Jaihind Travels Atta Pune Available Only Exchange Pune To Kolhapur Sedan Atta And Mazhi Kolhapur To Pune Sedan Chi 6.00 Pm - 8888737320
#
# 1/1 [==============================] - 0s 41ms/step
# Predicted label: Source= Shirdi Destination=Nashik
# Ertiga With Carrier Shirdi To Nashik Drop Time Urgent Urgent Urgent Vijay Ahire 8208520486
#
# 1/1 [==============================] - 0s 35ms/step
# Predicted label: Source= Shirdi Destination=Nashik
# Ertiga With Carrier Shirdi To Nashik Drop Time Urgent Urgent Urgent Vijay Ahire 8208520486
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source=Shirdi Destination=Mumbai
# Shirdi To Mumbai Drop Time:-Arjent Ertiga Including Toll And Parking Please Travels 9595645757
#
# 1/1 [==============================] - 0s 35ms/step
# Predicted label: Source=Shirdi Destination=Mumbai Bandra
# Shirdi To Mumbai Thane Drop Swift Dizer 11.00Am Any Interest Mi 9860331325
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source=Pune  Destination=Mumbai Airport
# Only Diseal Sedan Car With Carrier Chichwad ( Pune ) To Mumbai Airport Drop Tomorrow Morning = 11.30 Am New Rate = 2700 Rs + Parking Any Takers = 7262048764
#
# 1/1 [==============================] - 0s 38ms/step
# Predicted label: Source= Shirdi Destination=Thane Mumbai
# 3/4/2023 Shirdi To Thane Mumbai Drop Sedan 11.30Am 3500Rs All'Included Amount 7558681902 Good Luck Taxi
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source= Ulhasnagar Destination=Mumbai Airport
# Booking_ : Ertiga W/C From Ulhasnagar To Mumbai Airport At 8:00 Pm Today For Rs 1600 + Toll On 9890288112 _Note : Only Advance Gpay ._
#
# 1/1 [==============================] - 0s 39ms/step
# Predicted label: Source=Dapoli Destination=Pune
# Dapoli To Pune Car Type :- Sedan Time :- Today Urjent Me :- 9768868301
#
# 1/1 [==============================] - 0s 39ms/step
# Predicted label: Source=Nagar  Destination=Shirdi
# Time Arjant Sambhaji Nagar (Aurangabad) To Shirdi & Mumbai Panvel Drop Required Any Sedan Please 8668515898
#
# 1/1 [==============================] - 0s 37ms/step
# Predicted label: Source=Shirdi Destination=Mumbai
# Shirdi To Mumbai Drop Today 11Am Only Sedan Rs.. 9370488503
#
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source= Mumbai Destination=Nashik
# Hatchback Sedan Mumbai To Nashik Round Trip 9:30Am Anyone Interested 9146786692 7507786692
#
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source= Shirdi Destination=Mumbai
# Available Shirdi To Mumbai Drop @ 11 Am Required Sedan 7887387878
#
# 1/1 [==============================] - 0s 43ms/step
# Predicted label: Source=Nashik Destination=Mumbai
# Nashik To Mumbai Anderi Drop Today 8Am Only Ertica Rs 3200 All Including 9370488503
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source=Mumbai Destination=Pune
# Mumbai To Pune Drop Sedan Today At 7:30 Am 3Rd April 2023 Getmecab _ 7290885949 _
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source=Nashik Destination=Pune
# Nashik To Pune Hadapsar Drop Today 7Am Any Hatchback Or Sedan Rs 2500 All Inclusive 9370488503
#
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source=Nashik Destination=Pune
# Nashik To Pune Hadapsar Drop Now 4: 30Am Any Hatchback Or Sedan Rs 2500 All Inclusive 9370488503
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source=Pune Wakad Destination=Aurangabad
# Mumbai Andheri To Aurangabad Ertiga With Carrier Urgent 4500/- +Toll Parking Call 9518708741
#
# 1/1 [==============================] - 0s 42ms/step
# Predicted label: Source=Pune Wakad Destination=Aurangabad
# Mumbai Andheri To Aurangabad Ertiga With Carrier Urgent 4500/- +Toll Parking Call 9518708741
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source= Akola Destination=Pune
# Required Innova Crysta Tomorrow Morning 7.00Am Mumbai Mulund + Chembur To Pune Kharadi Drop Available Any Int Pl Me Ramesh Jadhav 8805595460 7385693263 Sign Duty
#
# 1/1 [==============================] - 0s 42ms/step
# Predicted label: Source= Shirdi Destination=Mumbai
# Tommarow Morning Available Shirdi To Mumbai Drop Time:07:30 Am 9665617687 Swift Dizare
#
# 1/1 [==============================] - 0s 31ms/step
# Predicted label: Source= Chembur Destination=Dapoli
# Tulja Bhavani Tours And Travels No: 2545 Trip: One Way Trip Cab: Sedan Gadi Date : 2/4/2023 Time : 9:30Pm : Nanded City To Ahmednagar Rs 2000 Call Me 9858647468 9326647468
#
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source=Shirdi Destination=Pune
# Shirdi To Pune Drop Swift Dizire 6Am 9511750005 9637011073
#
# 1/1 [==============================] - 0s 34ms/step
# Predicted label: Source=Nashik Destination=Surat
# Nashik To Surat Drop Time--9 .Pm Sedan Car 7020629456
#
# 1/1 [==============================] - 0s 34ms/step
# Predicted label: Source=Shirdi Destination=Mumbai
# Shirdi To Mumbai Drop Ertika 7Pm 9511750005 9637011073
#
# 1/1 [==============================] - 0s 38ms/step
# Predicted label: Source=Shirdi Destination=Mumbai
# Shirdi To Mumbai Any Sedan Tomarrow 8Am 3000 All Includ 9518708741
#
# 1/1 [==============================] - 0s 37ms/step
# Predicted label: Source=Shirdi Destination=Mumbai
# Shirdi To Mumbai Any Sedan Tomarrow 8Am 3000 All Includ 9518708741
#
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source= Pune Destination=Mumbai
# Only Innova Crysta T Permit Pune To Mumbai Return 2 Day 18 600 + Toll Tax Parking Extra Payment Cash Me 9011995733
#
# 1/1 [==============================] - 0s 39ms/step
# Predicted label: Source= Pune Destination=Pimpri Chinchwad
# Hadshi Pune To Pimpri Chinchwad Drop Pune Sedan Ac Car Required Time 05:30 Pm Om Sai Travels One Way Rate Leena Pawar 8624059496
#
# 1/1 [==============================] - 0s 35ms/step
# Predicted label: Source= Solapur Destination=Pune
# Return Trip No:643 Date : 06|04|2023 To 07|04|2023 Pick Up Time= 01:00 Pm Vehicle :- 10 Sitter Ac Only -: Pune To Solapur To Pune (Toll Parking Included) 7263972202 Kavya Tours & Travels
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source=Lonavla Destination=Mumbai
# Lonavla To Mumbai Urgent Sedan 9518708741
#
# 1/1 [==============================] - 0s 34ms/step
# Predicted label: Source=Shirdi Destination=Pune
# Shirdi To Pune Tomarrow 7Am Only Eartiga 9518708741
#
# 1/1 [==============================] - 0s 35ms/step
# Predicted label: Source= Shirdi Destination=Mumbai Powai
# Urjent Shirdi To Mumbai Powai Drop Sedan Car 4000Rs Including Toll 8830731947
#
# 1/1 [==============================] - 0s 34ms/step
# Predicted label: Source= Nagar Destination=Nashik
# Date 2/ /04/23 Time Chatrapati Sambhaji Nagar To Nashik Drop Etios Ac / Dzire Ac Jay Gajanan Mauli Contact Number 8421081111 Thanks
#
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source= Nagar Destination=Nashik
# Date 02/04/23 Time Urgent Sambhaji Nagar To Nashik Drop Etios Ac / Dzire Ac Jay Gajanan Mauli Contact Number 8421081111 Thanks
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source=Ahmadnagar Destination=Pune
# Rahuri To Pune Any Sedan Urgent 9518708741
#
# 1/1 [==============================] - 0s 40ms/step
# Predicted label: Source= Nashik Destination= Pune
# 2/4/2023 Nashik To Hadpsar Pune Drop Sedan 4.15Pm 2500Rs All'Included Amount 7558681902 Good Luck Taxi
#
# 1/1 [==============================] - 0s 40ms/step
# Predicted label: Source= Nagar Destination=Pune
# Date 02/04/23 Time Urgent Ahmadnagar Sakshi Nagar To Pune Drop Rs 2000 Etios Ac / Dzire Ac Jay Gajanan Mauli Contact Number 8421081111 Thanks
#
# 1/1 [==============================] - 0s 35ms/step
# Predicted label: Source= Nagar Destination=Pune
# Date 02/04/23 Time Urgent Ahmadnagar Sakshi Nagar To Pune Drop Etios Ac / Dzire Ac Jay Gajanan Mauli Contact Number 8421081111 Thanks
#
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source= Pune Destination=Sangamner
# Toyota Etios 4+1 Available In Pune Pune To Nashik Pune To Shirdi Pune To Trambak Pune To Sinner Pune To Sangamner Plz Call Me . 9503608786
#
# 1/1 [==============================] - 0s 35ms/step
# Predicted label: Source=Nashik  Destination=Mumbai
# Nashik City To Mumbai Goregav Filmcity Drop Sedan Car Time 4.00 Pm 2400 Toll Included Vijay 7709212799
#
# 1/1 [==============================] - 0s 35ms/step
# Predicted label: Source=Kolhapur Destination=Pune
# Kolhapur To Pune Sedan Today 3Pm Any Hatchback Or Sedan Rs . 9370488503
#
# 1/1 [==============================] - 0s 37ms/step
# Predicted label: Source= Nagar Destination=Pune
# Date 02/04/23 Time 1:20Pm Ahmadnagar Sakshi Nagar To Pune Drop Etios Ac / Dzire Ac Jay Gajanan Mauli Contact Number 8421081111 Thanks
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source= Nashik Destination=Bavdhan Pune
# _ Nashik To Bavdhan Pune Drop _ Only Pickup Car Sedan Aura Xcent Dzire Required_ Neat A Clean Car _Ac Car_ _Advance Gp Phone Pay_ Date:-02/04/2023 Time :- Now _ Cash @ 2700/- All Including _ Pari Tours & Travels _ Mukund Nikam _ _+918888731463_
#
# 1/1 [==============================] - 0s 45ms/step
# Predicted label: Source= Nagar Destination=Pune
# Date 02/04/23 Time 1.00Pm Ahmadnagar Sakshi Nagar To Pune Drop Etios Ac / Dzire Ac Jay Gajanan Mauli Contact Number 8421081111 Thanks
#
# 1/1 [==============================] - 0s 45ms/step
# Predicted label: Source=Trimbak Destination=Baner
# Trimbak To Baner (Pune) Drop Sedan .Clean.Ac Car Time--12:50Pm Today Amount--0000 7020629456
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source=Nashik Destination=Pune
# Nashik To Pune Drop Sedan Car Time 5.00Pm Mr. Amol Chavhan Call Me. 7517706750
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source= Panchgani Destination=Pune Airport
# Tomorrow 9Am Ertiga With Carrier Panchgani To Pune Airport 3000/ All Included Call9860306611
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source=Nashik Destination=Pune Baner
# Nashik To Pune Baner Drop Today 1Pm Only Sedan Rs 2500 All Inclusive 9370488503
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source=Mumbai Andheri Destination=Pune
# Hatchback One Way Drop Mumbai Andheri To Pune Viman Nagar Drop Today 11.30 Am 7400001075
#
# 1/1 [==============================] - 0s 37ms/step
# Predicted label: Source= Nagar Destination=Pune
# Date 02/04/23 Time 1.00Pm Ahmadnagar Sakshi Nagar To Pune Drop Etios Ac / Dzire Ac Jay Gajanan Mauli Contact Number 8421081111 Thanks
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source=Pune  Destination=Mumbai Goregaon
# Today Time 8 Pm Pune Kothrud To Mumbai Goregaon Dorp Cab Innova Crysta 7 Seater 4500/ Including Only Advance Payment Me 9527833075 Sainathtaxi
#
# 1/1 [==============================] - 0s 31ms/step
# Predicted label: Source= Dapoli Destination=Pune
# Advance 3/4/23 10Am Dapoli To Pune Hatchback Drop 80105 58818
#
# 1/1 [==============================] - 0s 37ms/step
# Predicted label: Source=Kalyani Nagar Destination= Bandra
# Need . Innova With Career Pune Kalyani Nagar To Bombay Bandra Drop Time 12.15 Pm Rs. 3800 All Inq Mo. 9130428755
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source=Shirdi Destination=Mumbai
# Shirdi To Mumbai (Juhu) Drop Time:-Arjent Ertiga Including Toll And Parking Please Travels 9595645757
#
# 1/1 [==============================] - 0s 38ms/step
# Predicted label: Source= Mumbai Destination=Pune
# Exchange Car... Arjent Mumbai To Pune Drop . Ertiga ..... & Ertiga Mumbai . Mumbai Pune Sedan Ertiga Drop . Ranjit Patil Rp 9960869689
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source=Karjat Destination=Pune
# Karjat To Pune Kharadi Drop Cab Ertiga With Carrier Time Urjent 9890802409
#
# 1/1 [==============================] - 0s 40ms/step
# Predicted label: Source=Pune  Destination=Pandharpur
# Today 12 Pm Pune Hadpssar To Pandharpur Drop Car Sedan Cng Rs 3000/ Any Interested Me 9527504444
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source=Kalyani Nagar Destination= Bandra
# Need . Innova With Career Pune Kalyani Nagar To Bombay Bandra Drop Time 12.15 Pm Rs. 3700 All Inq Mo. 9130428755
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source=Shirdi Destination=Mumbai
# Shirdi To Mumbai Drop Ertiga Car Career 11Am 9922187007 9922832002
#
# 1/1 [==============================] - 0s 35ms/step
# Predicted label: Source= Solapur Destination=Pune
# Need Sedan Ac Time 1.00 Pm Solapur To Pune Keshav Nagar Only Drop +919225555514
#
# 1/1 [==============================] - 0s 38ms/step
# Predicted label: Source=Trimbak Destination=Baner
# Bharuch To Mumbai Ulhasnagar Drop Today 10Am Only Sedan Rs 5000 All Including 9370488503
#
# 1/1 [==============================] - 0s 37ms/step
# Predicted label: Source=Kalyani Nagar Destination= Bandra
# Need . Innova With Career Pune Kalyani Nagar To Bombay Bandra Drop Time 12.15 Pm Rs. 3600 All Inq Mo. 9130428755
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source= Karad Destination=Pune
# Need Sedan Ac Time 10Am Karad To Pune Only Drop 8484901265
#
# 1/1 [==============================] - 0s 38ms/step
# Predicted label: Source=Shirdi Destination=Pune
# Shirdi To Pune Sedan Car 2/4/2023 Time 1.30 7397820427
#
# 1/1 [==============================] - 0s 34ms/step
# Predicted label: Source=Mumbai Colaba Destination=Kolhapur
# Need = Innova Wc From = Mumbai Colaba To Kolhapur Drop Date = 02/04/23 Time = 12:30 Pm _ Call _ = 07887801717 Sandesh
#
# 1/1 [==============================] - 0s 34ms/step
# Predicted label: Source= Shirdi Destination=Mumbai Bandra
# Today 1Pm Afternoon 1 Pm At Need Inova Car Only Shirdi To Mumbai Bandra Drop 5000 9518511684
#
# 1/1 [==============================] - 0s 30ms/step
# Predicted label: Source= Shirdi Destination=Mumbai
# Sedan Shirdi To Mumbai Drop Time 10 Am 8856000999
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source= Shirdi Destination=Mumbai
# Time Arjant Shirdi To Mumbai Drop Required Ertiga W/C Please 8668515898
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source=Nashik Destination=Mumbai
# Nashik To Mumbai Dorp Sedan Car Time Abi Urgent 9960786333
#
# 1/1 [==============================] - 0s 31ms/step
# Predicted label: Source=Pune Airport Destination=Shirdi
# Pune Airport To Shirdi Drp Only Eatiga 9518708741
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source=Alibag Revdanda Destination= Mumbai
# Alibag Revdanda To Car Mumbai Ertiga With Carrier 9518708741
#
# 1/1 [==============================] - 0s 35ms/step
# Predicted label: Source= Shirdi Destination=Mumbai Andheri
# Time Morning 08.30.A.M Shirdi To Mumbai Andheri Drop Required Ertiga W/C Please 8668515898
#
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source= Satara Destination=Mumbai
# Bookings Satara To Mumbai Ertiga 7:00 Am 4700 9518708741
#
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source=Satara Destination=Mumbai
# Satara To Mumbai Car Type :- Ertiga Time :- 8 Am Me :- 9768868301
#
# 1/1 [==============================] - 0s 49ms/step
# Predicted label: Source=Satara Destination=Mumbai
# Satara To Mumbai Car Type :- Ertiga Time :- 8 Am Me :- 9768868301
#
# 1/1 [==============================] - 0s 55ms/step
# Predicted label: Source=Mahabaleshwar Destination=Pune
# Mahabaleshwar To Pune Drop Time.09:30Am Swift Dzire Car G Pay Advance Payment Mm 9922786318
#
# 1/1 [==============================] - 0s 35ms/step
# Predicted label: Source=Shirdi Destination=Mumbai
# Shirdi To Mumbai Drop Swift Dizire 5Am 9511750005 9637011073
#
# 1/1 [==============================] - 0s 31ms/step
# Predicted label: Source= Shirdi Destination=Mumbai Airport
# 02 April 2023. Available. Shirdi To Shani Shinganapur & Mumbai Juhu Dorp. Time : 07:00 Am. Require : Sedan . : +919689529159 +919422228468 . 02 April 2023 . Available . Shirdi To Mumbai Airport Dorp . Time : 07:00 Am . Require : Sedan . : +919689529159 +919422228468 . More Info :- Jeevan Tour'S & Travel'S Shirdi . In Case Of Any Discrepancy Contact Us On.
#
# 1/1 [==============================] - 0s 37ms/step
# Predicted label: Source= Pune Destination=Mumbai
# Exchange Car... 02:15 Am Pune To Mumbai Drop . Sedan ..... & Ertiga Mumbai 05 :00 Am . Mumbai Pune Sedan Ertiga Drop . Ranjit Patil Rp 9969869689
#
# 1/1 [==============================] - 0s 31ms/step
# Predicted label: Source=Mumbai Airport Destination=Pune
# Mumbai Airport To Pune Drop Only Innova Crysta Time 1:00 A.M. Please Me Suresh Mama 9860423919
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source= Mahabaleshwar Destination= Pune
# Need = Sedan Mahabaleshwar To Warje Pune Drop Tim = Tomorrow 12.00Pm = 8888299923/ 9834436627
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source=Pune  Destination=Andheri
# Date 01/04/23 Pickup :06:00Am 1)Pune Dhanori To Mahabaleshwr Round Trip Dezire Xcent Pickup Time: 10:30Am 2)Pune Aundh To Solapur Drop Desire Xcent 3) Pune Vimannagar To Andheri West Drop Ya Round Trip Time : 06:30Am Cab : Swift Desire Xcent Contact Number 7058376670 Only Nearby Thanks
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source=Kalyani Nagar Destination= Bandra
# Need Innova Tomorrow Pune Kalyani Nagar To Bombay Bandra Drop Time. 12.45 Pm Rs. 3500 All Inq Mo. 9130428755
#
# 1/1 [==============================] - 0s 31ms/step
# Predicted label: Source= Pune Destination=Mumbai
# Exchange 2 April Take Tomorrow Morning 3.30 Am Pune Kondwa To Girgaon Mumbai Return For Sedan Give Me Pune To Mumbai Early Morning Drop For Ertiga Any Interested 7775095567
#
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source= Pune Destination=Mumbai
# 1 Day Return Pune To Mumbai Car Type :- Innova Time :- Tomorrow 8 Am Me :- 9768868301
#
# 1/1 [==============================] - 0s 34ms/step
# Predicted label: Source= Wakad Destination=Nashik
# _02-April--2023 Vehicle Type: Sedan (Diesel) Duty: Wakad To Nashik Drop Time: 06:00 Am Amount Rs 2800/- (Including Toll) Taxi Service 9762001053
#
# 1/1 [==============================] - 0s 34ms/step
# Predicted label: Source=Mumbai Powai Destination=Pune
# Hatchback One Way Drop Mumbai Powai To Pune Balewadi Drop Today 6.30 Pm 7400001075
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source=Khalapur  Destination=Pune Station
# Urgently Required New Model Ertica Khalapur Toll To Pune Station Drop Rs3000 All Including Interested Me 9527379527 Rajveer Tours And Travels
#
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source= Pune Destination=Mumbai
# 1 Day Return Pune To Mumbai Car Type :- Innova Time :- Tomorrow 8 Am Me :- 9768868301
#
# 1/1 [==============================] - 0s 37ms/step
# Predicted label: Source=Shikrapur Pune Destination=Mumbai
# Shikrapur Pune To Mumbai Any Sedan 9518708741
#
# 1/1 [==============================] - 0s 32ms/step
# Predicted label: Source= Pune Destination=Mumbai
# 1 Day Return Pune To Mumbai Car Type :- Innova Time :- Tomorrow 8 Am Me :- 9768868301
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source=Mumbai Airport Destination=Lonavla
# Car Inova Cresta Mumbai Airport To Lonavla Mo No 9082415613 Urjunt
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source=Nashik Destination=Shirdi
# Nashik To Shirdi K Drop Sedan 5Pm 9822898617
#
# 1/1 [==============================] - 0s 35ms/step
# Predicted label: Source=Sangamner Destination=Pune
# Amravati To Pune Drop Tomorrow Morning Only Ertica Rs.. 9370488503
#
# 1/1 [==============================] - 0s 50ms/step
# Predicted label: Source= Kolhapur Destination=Mumbai
# Kolhapur To Pune Drop Kolhapur To Mumbai Drop Innnova 2/4/23 7Am 7507013712 50/50
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source=Mumbai Pawai Destination=Aurangabad
# Date 1/04/23 Time 2.30Pm Mumbai Pawai To Aurangabad Drop Etios Ac /Dzire Ac Jay Gajanan Mauli Contact Number 8421081111 Thanks
#
# 1/1 [==============================] - 0s 31ms/step
# Predicted label: Source= Nanded Destination=Pune
# Date 03/04/24 Time 06.00 Am Innova Car Only 04 Days Outstation Pune To Aurangabad To Nanded To Pune Me 9011995733
#
# 1/1 [==============================] - 0s 33ms/step
# Predicted label: Source= Pune Destination=Latur
# Today Pune To Latur Drop Available Sedan Car 9822143030
#
# 1/1 [==============================] - 0s 38ms/step
# Predicted label: Source= Hyderabad Destination=Pune
# Innova Available Hyderabad To Pune Me 8080403095
#
# 1/1 [==============================] - 0s 35ms/step
# Predicted label: Source=Ahmednagar Destination=Vashi Mumbai
# Ahmednagar To Vashi Mumbai Packing Roll Qty 6 Approx Weight 120Kg Require Sedan Time Urgent
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source=Shirdi Destination=Mumbai
# Shirdi To Mumbai Drop Swift Dizire 1Pm 9511750005 9637011073
#
# 1/1 [==============================] - 0s 46ms/step
# Predicted label: Source=Shirdi Destination=Mumbai Airport
# Shirdi To Mumbai Airport Drop Today Evening 7:30Pm Only Ertica Rs 4200 All Including 9370488503
#
# 1/1 [==============================] - 0s 49ms/step
# Predicted label: Source= Mumbai Destination=Pune
# Exchange Take Pune To Mumbai Varsowa Return For Sedan Car 10:45Am Give Me Mumbai To Pune For Sedan Car Today Now Any Time Feroz 9881128867
#
# 1/1 [==============================] - 0s 52ms/step
# Predicted label: Source=Pune  Destination=Mumbai
# Date 01/04/23 Pickup :12:45Pm Pune Vishrantwadi To Mumbai Niljegaon Near Dombivali Drop Dezire Xcent Only Disel Contact Number 9730020148 Only Nearby Thanks
#
# 1/1 [==============================] - 0s 54ms/step
# Predicted label: Source=Mumbai Dombivli Destination=Pune
# Only Near By Sedan One Way Drop Mumbai Dombivli To Pune Drop Today Time Urgent 7400001075
#
# 1/1 [==============================] - 0s 60ms/step
# Predicted label: Source=Nashik Destination=Dhule
# Nashik To Dhule Drop Today 10Am Only Sedan Rs 2500 All Including 9370488503
#
# 1/1 [==============================] - 0s 46ms/step
# Predicted label: Source=Pune  Destination= Airport
# Need Innova With Career Time. 10 Am Pune Vishrantwadi To Bombay Airport Drop Rs. 3700 All Inq Mo. 9130428755
#
# 1/1 [==============================] - 0s 50ms/step
# Predicted label: Source=Kolhapur Destination=Mumbai
# Kolhapur To Mumbai Drop 7507013712 Arjant Sedan
#
# 1/1 [==============================] - 0s 46ms/step
# Predicted label: Source= Pune Destination=Karjat
# Magar Patta Pune To Karjat Drop Time Urgent 2200/- All Including Sedan Cab 9773777750
#
# 1/1 [==============================] - 0s 48ms/step
# Predicted label: Source= Kolhapur Destination=Satara
# Kolhapur To Thane Drop Sedan Car Time Urgent Call Me 9834232664
#
# 1/1 [==============================] - 0s 50ms/step
# Predicted label: Source= Surat Destination=Vapi
# Kolhapur To Thane Drop Sedan Car T Permit Time Urgent Call Me 8805276410
#
# 1/1 [==============================] - 0s 50ms/step
# Predicted label: Source=Nashik  Destination=Mumbai
# _Booking Sedan Car_ _Time 07.00 Am_ _Pickup :- Shirdi_ _To_ Nashik Darshan To Mumbai Drop_ _Cash_ _If Instrested Call_ _+919075777125_
#
# 1/1 [==============================] - 0s 53ms/step
# Predicted label: Source=Pune Destination=Sangli
# Pune To Sangli Car Type :- Innova With Carrier Time :- Tomorrow 10 Am Me :- 9768868301
#
# 1/1 [==============================] - 0s 44ms/step
# Predicted label: Source=Pune Destination=Sangli
# Pune To Sangli Car Type :- Innova With Carrier Time :- Tomorrow 10 Am Me :- 9768868301
#
# 1/1 [==============================] - 0s 55ms/step
# Predicted label: Source=Shirdi Destination=Pune
# Shirdi To Pune Any Sedan Urgent 9518708741
#
# 1/1 [==============================] - 0s 46ms/step
# Predicted label: Source=Pune Destination=Sangli
# Pune To Sangli Car Type :- Innova With Carrier Time :- Tomorrow 10 Am Me :- 9768868301
#
# 1/1 [==============================] - 0s 57ms/step
# Predicted label: Source=Pune Airport Destination=Solapur
# Date 01/04/23 Pickup :07:45Am Pune Airport To Solapur Drop Dezire Xcent Contact Number 7058376670 Only Nearby Thanks
#
# 1/1 [==============================] - 0s 49ms/step
# Predicted label: Source=Pune Destination=Sangli
# Pune To Sangli Car Type :- Innova With Carrier Time :- Tomorrow 10 Am Me :- 9768868301
#
# 1/1 [==============================] - 0s 70ms/step
# Predicted label: Source= Pune Destination=Mumbai Airport
# Requirement Time : 10 : 30Pm Pune To Mumbai Airport Innova W/C One Way Call : +91 9518949487 Aai Ekvira Tours & Travels
#
# 1/1 [==============================] - 0s 214ms/step
# Predicted label: Source=Nagar  Destination=Nashik
# _ Sambhaji Nagar Cidco To Nashik Drop _ Only Pickup Car Sedan Aura Xcent Dzire Required_ Neat A Clean Car _Ac Car_ _Advance Gp Phone Pay_ Date:-31/03/2023 Time :- Now _ Cash @ ..../- All Including _ Pari Tours & Travels _ Mukund Nikam _ _+918888731463_
#
# 1/1 [==============================] - 0s 172ms/step
# Predicted label: Source=Pune  Destination=Pandharpur Akkalkot
# Pune Chikhali To Pandharpur Akkalkot Tuljapur Swift Dzire 2 Divas Me 8788900772
#
# 1/1 [==============================] - 0s 60ms/step
# Predicted label: Source= Nashik Destination=Mumbai Airport
# Nice 2 Innova Car 7+1 Raat 8 Pm Nashik To Mumbai Airport Drop. Advance Google Phone Pay. 8329819110
#
# 1/1 [==============================] - 0s 52ms/step
# Predicted label: Source=Rajkot  Destination=Pune
# Ertiga Cab Rajkot City To Pune City Date - 07 April 2023 Morning- 05.30 Am 10 000 Rs All Included. Rajesh- India Tourism. 9820020313 Note- . Note- This Is Private Booking. Note- Neat And Clean Only.
#
# 1/1 [==============================] - 0s 53ms/step
# Predicted label: Source= Pune Destination=Mumbai
# New Required Booking... Today Only For Exchange... Take... Mumbai (Airport) To Pune (Tathawade) Sedan Car Today 05:00Pm Give Me... Pune To Mumbai Sedan Drop Arjunt.... Vip Cab (Vijay Jagdale) 7387595095
#
# 1/1 [==============================] - 0s 50ms/step
# Predicted label: Source=Pune  Destination= Nagar
# Date 31/03/23 Time Urgent Pune Vidyapith To Sambhaji Nagar Drop Drop Etios Ac / Dzire Ac Jay Gajanan Mauli Contact Number 8421081111 Thanks
#
# 1/1 [==============================] - 0s 155ms/step
# Predicted label: Source=Nokha  Destination=Jaipur
# Nokha Rajasthan To Jaipur Next Day Return Cab : Innova Time : 4: 00 Pm Date : 31 March 2023 Call Me : 9167585424 No Advance Direct Payment From Party
#
# 1/1 [==============================] - 0s 99ms/step
# Predicted label: Source= Mahabaleshwar Destination=Mumbai
# Ertiga One Way Drop Mahabaleshwar To Mumbai Drop Tomorrow Morning 9 Am 7400001075
#
# 1/1 [==============================] - 0s 45ms/step
# Predicted label: Source=Pune Pimpri Destination=Mumbai Andheri
# Date 31/03/23 Pickup :Urjent Pune Pimpri To Mumbai Andheri East Dezire Xcent Contact Number 7058376670 Only Nearby Thanks
#
# 1/1 [==============================] - 0s 39ms/step
# Predicted label: Source=Nokha  Destination=Jaipur
# Nokha Rajasthan To Jaipur Next Day Return Cab : Innova Time : 4: 00 Pm Date : 31 March 2023 Call Me : 9167585424
#
# 1/1 [==============================] - 0s 30ms/step
# Predicted label: Source=Nokha  Destination=Jaipur
# Nokha Rajasthan To Jaipur Next Day Return Cab : Innova Time : 4: 00 Pm Date : 31 March 2023 Call Me : 9167585424
#
# 1/1 [==============================] - 0s 34ms/step
# Predicted label: Source=Jamkhed Destination=Pune
# Jamkhed To Pune Drop Time.03:00Pm Swift Dzire Car Rs .4000 +917065752028
#
# 1/1 [==============================] - 0s 34ms/step
# Predicted label: Source= Pune Destination=Mumbai
# Need Inova Cryasta Pune To Mumbai Urgent 9518708741
#
# 1/1 [==============================] - 0s 36ms/step
# Predicted label: Source= Nagar Destination=Pune Goregaon
# Pune Shivaji Nagar To Pune Goregaon Drop Cab : Innova Wc Time : 02 : 00 Pm Rate : 4000 Date : 31 March 2023 Call Me : 07020834024

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 202, 100)          978100
#
#  bidirectional_9 (Bidirectio  (None, 202, 256)         234496
#  nal)
#
#  dropout_3 (Dropout)         (None, 202, 256)          0
#
#  bidirectional_10 (Bidirecti  (None, 202, 128)         164352
#  onal)
#
#  bidirectional_11 (Bidirecti  (None, 128)              98816
#  onal)
#
#  dense_4 (Dense)             (None, 32)                4128
#
#  dense_5 (Dense)             (None, 4321)              142593
#
# =================================================================
# Total params: 1,622,485
# Trainable params: 1,622,485
# Non-trainable params: 0
# _________________________________________________________________
